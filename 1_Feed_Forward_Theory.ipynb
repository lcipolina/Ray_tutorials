# %% [markdown]
# <a href="https://colab.research.google.com/github/lcipolina/Ray/blob/main/1_Feed_Forward_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## From Feed Forward to Pytorch

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### Typical Linear Regression - Note how we obtain one set of parameters only

# %%
# !curl -sS https://i.imgur.com/bXga7nb.png> kp.jpg 
img= cv2.imread("kp.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1016x633 at 0x7FBFFA151490>

# %% [markdown]
# Usually this is solved using the Normal equations

# %%
# !curl -sS https://i.imgur.com/VDGiKtd.jpg > kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (700,300), interpolation = cv2.INTER_AREA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x300 at 0x7FBFF90ED050>

# %% [markdown]
# Batch training allows us to work with big data set

# %%
# !curl -sS https://i.imgur.com/aTNTTur.jpg> kp.jpg 
img= cv2.imread("kp.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1115x308 at 0x7FBFFA151050>

# %% [markdown]
# ### Batch training

# %%
# !curl -sS https://i.imgur.com/n6u39GR.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,600), interpolation = cv2.INTER_AREA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FBFF90F4A90>

# %%
# !curl -sS https://i.imgur.com/5iV6jEI.jpg> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,500), interpolation = cv2.INTER_AREA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x500 at 0x7FBFF90F4BD0>

# %%
# !curl -sS https://i.imgur.com/TfpJucn.png > kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,650), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x650 at 0x7FBFF90EE250>

# %% [markdown]
# ## Convex Function Minimization with Feed Forward and Back Propagation

# %%
# !curl -sS https://i.imgur.com/TwqXmYE.jpg> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (700,300), interpolation = cv2.INTER_AREA)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x300 at 0x7FC00A35E3D0>

# %% [markdown]
# The incremental steps are the "learning rate"

# %%
# !curl -sS https://i.imgur.com/Zu16Knc.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,600), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FC007D0CF50>

# %%
# !curl -sS https://i.imgur.com/RM1SCjS.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,500), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x500 at 0x7FBFF9109B50>

# %%
# !curl -sS https://i.imgur.com/BT63it8.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,500), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x500 at 0x7FBFF9109F90>

# %% [markdown]
# ### Feed Forward as an Optimization Loop
# The Learning Rate is part of the Parameter Updating Block

# %%
# !curl -sS https://i.imgur.com/DUN0Mzs.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (700,500), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=700x500 at 0x7FBFF90ED890>

# %% [markdown]
# ## Back Propagation and Learning Rate
#
# https://hmkcode.com/ai/backpropagation-step-by-step/

# %%
# !curl -sS https://i.imgur.com/NwF9RvI.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (900,700), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=900x700 at 0x7FBFF90DA490>

# %%
# !curl -sS https://i.imgur.com/9blBPlf.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (800,600), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FBFF90F94D0>

# %%
# !curl -sS https://i.imgur.com/RdKKlyq.png> kp.jpg 
img= cv2.imread("kp.jpg")
img= cv2.resize(img, (950,900), interpolation = cv2.INTER_CUBIC)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=950x900 at 0x7FBFF90ED6D0>
